# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\user'

# %%
car_sales = pd.read_csv("7.1 car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
#how to plot a graph 
car_sales['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
#how to make histogram
car_sales['Make'].hist()
# Out:
# <AxesSubplot:>

# %%
#how to export data
car_sales.to_csv("Exported_car-sales.csv", index=False)

# %%
pd.read_csv("Exported_car-sales.csv")
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales['Colour'] = car_sales['Colour'].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  WHITE         150043      4   $4,000.00
# 1   honda    RED          87899      4   $5,000.00
# 2  toyota   BLUE          32549      3   $7,000.00
# 3     bmw  BLACK          11179      5  $22,000.00
# 4  nissan  WHITE         213095      4   $3,500.00
# 5  toyota  GREEN          99213      4   $4,500.00
# 6   honda   BLUE          45698      4   $7,500.00
# 7   honda   BLUE          54738      4   $7,000.00
# 8  toyota  WHITE          60000      4   $6,250.00
# 9  nissan  WHITE          31600      4   $9,700.00

# %%
sm = pd.read_csv('9.2 car-sales-missing-data.csv')

# %%
sm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# bmw     0  0  1
# honda   0  3  0
# nissan  0  2  0
# toyota  1  3  0

# %%
sm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
sm.head()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
sm.tail()
# Out:
#      Make Colour  Odometer  Doors   Price
# 5  Toyota  Green       NaN    4.0  $4,500
# 6   Honda    NaN       NaN    4.0  $7,500
# 7   Honda   Blue       NaN    4.0     NaN
# 8  Toyota  White   60000.0    NaN     NaN
# 9     NaN  White   31600.0    4.0  $9,700

# %%
sm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  6 non-null      float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
sm.shape
# Out:
# (10, 5)

# %%
sm.size
# Out:
# 50

# %% [markdown]
# ## HOW TO CHECK FOR NULL VALUE

# %%
sm.isna
# Out:
# <bound method DataFrame.isna of      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700>

# %%
sm.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
sm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ## GRAPHIAL REPRESENTATION OF THE COLUMN "ODOMETER"

# %%
sm['Odometer'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## DROP THE NULL VALUE FOR EACH ROW

# %%
drop_sm = sm.dropna()

# %%
drop_sm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
sm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ## more info about the data

# %%
sm.describe()
# Out:
#             Odometer  Doors
# count       6.000000    9.0
# mean    92302.666667    4.0
# std     76489.805168    0.5
# min     11179.000000    3.0
# 25%     38700.000000    4.0
# 50%     73949.500000    4.0
# 75%    134507.000000    4.0
# max    213095.000000    5.0

# %% [markdown]
# ## getting the mean value for the Column without NAn to fill the NaN value

# %%
sm
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
mn = sm['Odometer'].mean()

# %%
mn
# Out:
# 92302.66666666667

# %% [markdown]
# ## fill the Odometer column with mean gotten without the NaN

# %%
sm['Odometer'].fillna(mn,inplace = True)

# %%
sm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## Calculating the mean value for the Column 'Door' to fill up the nul value

# %%
mn = sm['Doors'].mean()

# %%
mn
# Out:
# 4.0

# %%
sm['Doors'].fillna(mn, inplace = True)

# %%
sm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## null value in "Colour" is being filled  with green

# %%
sm['Colour'].fillna('Green',inplace = True)

# %%
 sm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda  Green   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## Null value in "Make" is being filled with Toyota

# %%
sm['Make'].fillna('Toyota', inplace = True)

# %%
sm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda  Green   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9  Toyota  White   31600.000000    4.0   $9,700

# %%
sm['Price'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ## drop all the null value to get the rows without null value to calcuate the mean

# %%
drop_p = sm.dropna()

# %%
drop_p
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda  Green   92302.666667    4.0   $7,500
# 9  Toyota  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## the beneath info is used to remove the ($ sign, , comma or decimal point in an int)

# %%
drop_p['Price'] = drop_p['Price'].replace('[\$\,\.]', '', regex = True).astype(int)
# Out:
# <ipython-input-64-d8cbcc683534>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_p['Price'] = drop_p['Price'].replace('[\$\,\.]', '', regex = True).astype(int)

# %%
drop_p
# Out:
#      Make Colour       Odometer  Doors  Price
# 0  Toyota  White  150043.000000    4.0   4000
# 1   Honda    Red   87899.000000    4.0   5000
# 2  Toyota   Blue   92302.666667    3.0   7000
# 3     BMW  Black   11179.000000    5.0  22000
# 4  Nissan  White  213095.000000    4.0   3500
# 5  Toyota  Green   92302.666667    4.0   4500
# 6   Honda  Green   92302.666667    4.0   7500
# 9  Toyota  White   31600.000000    4.0   9700

# %%
meanp = drop_p['Price'].mean()

# %%
meanp
# Out:
# 7900.0

# %%
drop_p
# Out:
#      Make Colour       Odometer  Doors  Price
# 0  Toyota  White  150043.000000    4.0   4000
# 1   Honda    Red   87899.000000    4.0   5000
# 2  Toyota   Blue   92302.666667    3.0   7000
# 3     BMW  Black   11179.000000    5.0  22000
# 4  Nissan  White  213095.000000    4.0   3500
# 5  Toyota  Green   92302.666667    4.0   4500
# 6   Honda  Green   92302.666667    4.0   7500
# 9  Toyota  White   31600.000000    4.0   9700

# %%
sm.fillna(meanp, inplace = True)

# %%
sm
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda  Green   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0   7900.0
# 8  Toyota  White   60000.000000    4.0   7900.0
# 9  Toyota  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## removing the symbols from the number and converting the data into int

# %%
sm['Price'] = sm['Price'].replace('[\$\,\.]', '', regex = True).astype(int)

# %%
sm
# Out:
#      Make Colour       Odometer  Doors  Price
# 0  Toyota  White  150043.000000    4.0   4000
# 1   Honda    Red   87899.000000    4.0   5000
# 2  Toyota   Blue   92302.666667    3.0   7000
# 3     BMW  Black   11179.000000    5.0  22000
# 4  Nissan  White  213095.000000    4.0   3500
# 5  Toyota  Green   92302.666667    4.0   4500
# 6   Honda  Green   92302.666667    4.0   7500
# 7   Honda   Blue   92302.666667    4.0   7900
# 8  Toyota  White   60000.000000    4.0   7900
# 9  Toyota  White   31600.000000    4.0   9700

# %% [markdown]
# ## addition of new column 'Seats'

# %%
sm['Seats']= 5

# %%
sm
# Out:
#      Make Colour       Odometer  Doors  Price  Seats
# 0  Toyota  White  150043.000000    4.0   4000      5
# 1   Honda    Red   87899.000000    4.0   5000      5
# 2  Toyota   Blue   92302.666667    3.0   7000      5
# 3     BMW  Black   11179.000000    5.0  22000      5
# 4  Nissan  White  213095.000000    4.0   3500      5
# 5  Toyota  Green   92302.666667    4.0   4500      5
# 6   Honda  Green   92302.666667    4.0   7500      5
# 7   Honda   Blue   92302.666667    4.0   7900      5
# 8  Toyota  White   60000.000000    4.0   7900      5
# 9  Toyota  White   31600.000000    4.0   9700      5

# %%
sm['Price'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Fuel per 100Km is added to the column beneath

# %%
#column from python list
#fuel per Km was added to The beneath column 
fuel_economy= [7.5,9.2,5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.5] 
sm['Fuel per 100KM'] = fuel_economy
sm
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Fuel per 100KM
# 0  Toyota  White  150043.000000    4.0   4000      5             7.5
# 1   Honda    Red   87899.000000    4.0   5000      5             9.2
# 2  Toyota   Blue   92302.666667    3.0   7000      5             5.0
# 3     BMW  Black   11179.000000    5.0  22000      5             9.6
# 4  Nissan  White  213095.000000    4.0   3500      5             8.7
# 5  Toyota  Green   92302.666667    4.0   4500      5             4.7
# 6   Honda  Green   92302.666667    4.0   7500      5             7.6
# 7   Honda   Blue   92302.666667    4.0   7900      5             8.7
# 8  Toyota  White   60000.000000    4.0   7900      5             3.0
# 9  Toyota  White   31600.000000    4.0   9700      5             4.5

# %% [markdown]
# ## Total fuel used is calculated by the Odometer / 100 multiply by the total amount of fuel used per 100KM

# %%
# the total fuel used by the the car is calculated by 
# the odometer /100 * fuel per kilometers
sm['Total Fuel used (L)'] = sm['Odometer']/100 * sm['Fuel per 100KM']

# %%
sm
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White  150043.000000    4.0   4000      5             7.5
# 1   Honda    Red   87899.000000    4.0   5000      5             9.2
# 2  Toyota   Blue   92302.666667    3.0   7000      5             5.0
# 3     BMW  Black   11179.000000    5.0  22000      5             9.6
# 4  Nissan  White  213095.000000    4.0   3500      5             8.7
# 5  Toyota  Green   92302.666667    4.0   4500      5             4.7
# 6   Honda  Green   92302.666667    4.0   7500      5             7.6
# 7   Honda   Blue   92302.666667    4.0   7900      5             8.7
# 8  Toyota  White   60000.000000    4.0   7900      5             3.0
# 9  Toyota  White   31600.000000    4.0   9700      5             4.5
#
#    Total Fuel consumption (L)  Total Fuel used (L)
# 0                11253.225000         11253.225000
# 1                 8086.708000          8086.708000
# 2                 4615.133333          4615.133333
# ...

# %%
del sm['Total Fuel consumption (L)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Fuel consumption (L)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-55aac6a2cedf> in <module>
# ...

# %%
sm
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White  150043.000000    4.0   4000      5             7.5
# 1   Honda    Red   87899.000000    4.0   5000      5             9.2
# 2  Toyota   Blue   92302.666667    3.0   7000      5             5.0
# 3     BMW  Black   11179.000000    5.0  22000      5             9.6
# 4  Nissan  White  213095.000000    4.0   3500      5             8.7
# 5  Toyota  Green   92302.666667    4.0   4500      5             4.7
# 6   Honda  Green   92302.666667    4.0   7500      5             7.6
# 7   Honda   Blue   92302.666667    4.0   7900      5             8.7
# 8  Toyota  White   60000.000000    4.0   7900      5             3.0
# 9  Toyota  White   31600.000000    4.0   9700      5             4.5
#
#    Total Fuel used (L)
# 0         11253.225000
# 1          8086.708000
# 2          4615.133333
# 3          1073.184000
# 4         18539.265000
# 5          4338.225333
# 6          7015.002667
# ...

# %% [markdown]
# ## The fuel per KM (fuel economy) is sorted in ascending order

# %%
sm.sort_values(by=['Fuel per 100KM'])
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 8  Toyota  White   60000.000000    4.0   7900      5             3.0
# 9  Toyota  White   31600.000000    4.0   9700      5             4.5
# 5  Toyota  Green   92302.666667    4.0   4500      5             4.7
# 2  Toyota   Blue   92302.666667    3.0   7000      5             5.0
# 0  Toyota  White  150043.000000    4.0   4000      5             7.5
# 6   Honda  Green   92302.666667    4.0   7500      5             7.6
# 4  Nissan  White  213095.000000    4.0   3500      5             8.7
# 7   Honda   Blue   92302.666667    4.0   7900      5             8.7
# 1   Honda    Red   87899.000000    4.0   5000      5             9.2
# 3     BMW  Black   11179.000000    5.0  22000      5             9.6
#
#    Total Fuel used (L)
# 8          1800.000000
# 9          1422.000000
# 5          4338.225333
# 2          4615.133333
# 0         11253.225000
# 6          7015.002667
# 4         18539.265000
# ...
